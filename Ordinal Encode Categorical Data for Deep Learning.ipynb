# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from keras.models import Sequential
from keras.layers import Dense

# %%
def load_dataset(path):
    # load the dataset as a pandas DataFrame
    df = pd.read_csv(path, header=None)
    # retrieve numpy array
    df = df.values
    # split into input (X) and output (y) variables
    features = df[:, :-1]
    target = df[:,-1]
    # format all fields as string
    features = features.astype(str)
    # reshape target to be a 2d array
    target = target.reshape((len(target), 1))
    return features, target

# %%
def prepare_inputs(features_train, features_test):
    oe = OrdinalEncoder()
    oe.fit(features_train)
    features_train_enc = oe.transform(features_train)
    features_test_enc = oe.transform(features_test)
    return features_train_enc, features_test_enc

# %%
def prepare_targets(target_train, target_test):
    le = LabelEncoder()
    le.fit(target_train)
    target_train_enc = le.transform(target_train)
    target_test_enc = le.transform(target_test)
    return target_train_enc, target_test_enc

# %%
features, target = load_dataset('D://DS//Stater_Projects//breastcancer.txt')

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.33, random_state=12345)

# %%
features_train_enc, features_test_enc = prepare_inputs(features_train, features_test)

# %%
target_train_enc, target_test_enc = prepare_targets(target_train, target_test)
# Out:
# D:\Packages\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
model = Sequential()
model.add(Dense(10, input_dim=features_train_enc.shape[1], activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(features_train_enc, target_train_enc, epochs=200, batch_size=16, verbose=2)
# Out:
# Epoch 1/200
# 12/12 - 23s - loss: 1.7790 - accuracy: 0.2984
# Epoch 2/200
# 12/12 - 0s - loss: 1.5886 - accuracy: 0.3246
# Epoch 3/200
# 12/12 - 0s - loss: 1.4332 - accuracy: 0.3560
# Epoch 4/200
# 12/12 - 0s - loss: 1.3236 - accuracy: 0.3508
# Epoch 5/200
# 12/12 - 0s - loss: 1.2434 - accuracy: 0.3455
# Epoch 6/200
# 12/12 - 0s - loss: 1.1832 - accuracy: 0.3665
# Epoch 7/200
# 12/12 - 0s - loss: 1.1281 - accuracy: 0.3979
# Epoch 8/200
# 12/12 - 0s - loss: 1.0871 - accuracy: 0.4031
# Epoch 9/200
# 12/12 - 0s - loss: 1.0515 - accuracy: 0.3927
# Epoch 10/200
# 12/12 - 0s - loss: 1.0174 - accuracy: 0.4136
# Epoch 11/200
# 12/12 - 0s - loss: 0.9875 - accuracy: 0.4188
# Epoch 12/200
# 12/12 - 0s - loss: 0.9626 - accuracy: 0.4293
# Epoch 13/200
# 12/12 - 0s - loss: 0.9378 - accuracy: 0.4293
# Epoch 14/200
# 12/12 - 0s - loss: 0.9142 - accuracy: 0.4398
# Epoch 15/200
# 12/12 - 0s - loss: 0.8921 - accuracy: 0.4450
# Epoch 16/200
# 12/12 - 0s - loss: 0.8722 - accuracy: 0.4555
# Epoch 17/200
# 12/12 - 0s - loss: 0.8499 - accuracy: 0.4555
# Epoch 18/200
# 12/12 - 0s - loss: 0.8313 - accuracy: 0.4660
# Epoch 19/200
# 12/12 - 0s - loss: 0.8111 - accuracy: 0.4764
# Epoch 20/200
# 12/12 - 0s - loss: 0.7925 - accuracy: 0.4817
# Epoch 21/200
# 12/12 - 0s - loss: 0.7751 - accuracy: 0.4764
# Epoch 22/200
# 12/12 - 0s - loss: 0.7581 - accuracy: 0.4869
# Epoch 23/200
# 12/12 - 0s - loss: 0.7424 - accuracy: 0.5131
# Epoch 24/200
# 12/12 - 0s - loss: 0.7279 - accuracy: 0.5550
# Epoch 25/200
# 12/12 - 0s - loss: 0.7134 - accuracy: 0.5654
# Epoch 26/200
# 12/12 - 0s - loss: 0.7011 - accuracy: 0.5812
# Epoch 27/200
# 12/12 - 0s - loss: 0.6894 - accuracy: 0.5864
# Epoch 28/200
# 12/12 - 0s - loss: 0.6782 - accuracy: 0.6021
# Epoch 29/200
# 12/12 - 0s - loss: 0.6684 - accuracy: 0.6178
# Epoch 30/200
# 12/12 - 0s - loss: 0.6585 - accuracy: 0.6335
# Epoch 31/200
# 12/12 - 0s - loss: 0.6465 - accuracy: 0.6702
# Epoch 32/200
# 12/12 - 0s - loss: 0.6370 - accuracy: 0.6963
# Epoch 33/200
# 12/12 - 0s - loss: 0.6287 - accuracy: 0.6963
# Epoch 34/200
# 12/12 - 0s - loss: 0.6190 - accuracy: 0.7016
# Epoch 35/200
# 12/12 - 0s - loss: 0.6118 - accuracy: 0.7068
# Epoch 36/200
# 12/12 - 0s - loss: 0.6050 - accuracy: 0.7120
# Epoch 37/200
# 12/12 - 0s - loss: 0.5982 - accuracy: 0.7173
# Epoch 38/200
# 12/12 - 0s - loss: 0.5926 - accuracy: 0.7173
# Epoch 39/200
# 12/12 - 0s - loss: 0.5872 - accuracy: 0.7173
# Epoch 40/200
# 12/12 - 0s - loss: 0.5821 - accuracy: 0.7173
# Epoch 41/200
# 12/12 - 0s - loss: 0.5783 - accuracy: 0.7173
# Epoch 42/200
# 12/12 - 0s - loss: 0.5754 - accuracy: 0.7225
# Epoch 43/200
# 12/12 - 0s - loss: 0.5703 - accuracy: 0.7173
# Epoch 44/200
# 12/12 - 0s - loss: 0.5671 - accuracy: 0.7173
# Epoch 45/200
# 12/12 - 0s - loss: 0.5633 - accuracy: 0.7173
# Epoch 46/200
# 12/12 - 0s - loss: 0.5604 - accuracy: 0.7277
# Epoch 47/200
# 12/12 - 0s - loss: 0.5579 - accuracy: 0.7330
# Epoch 48/200
# 12/12 - 0s - loss: 0.5555 - accuracy: 0.7330
# Epoch 49/200
# 12/12 - 0s - loss: 0.5528 - accuracy: 0.7330
# Epoch 50/200
# 12/12 - 0s - loss: 0.5509 - accuracy: 0.7277
# Epoch 51/200
# 12/12 - 0s - loss: 0.5488 - accuracy: 0.7277
# Epoch 52/200
# 12/12 - 0s - loss: 0.5481 - accuracy: 0.7330
# Epoch 53/200
# 12/12 - 0s - loss: 0.5451 - accuracy: 0.7382
# Epoch 54/200
# 12/12 - 0s - loss: 0.5434 - accuracy: 0.7330
# Epoch 55/200
# 12/12 - 0s - loss: 0.5425 - accuracy: 0.7330
# Epoch 56/200
# 12/12 - 0s - loss: 0.5416 - accuracy: 0.7277
# Epoch 57/200
# 12/12 - 0s - loss: 0.5404 - accuracy: 0.7277
# Epoch 58/200
# 12/12 - 0s - loss: 0.5393 - accuracy: 0.7277
# Epoch 59/200
# 12/12 - 0s - loss: 0.5376 - accuracy: 0.7330
# Epoch 60/200
# 12/12 - 0s - loss: 0.5357 - accuracy: 0.7382
# Epoch 61/200
# 12/12 - 0s - loss: 0.5346 - accuracy: 0.7382
# Epoch 62/200
# 12/12 - 0s - loss: 0.5343 - accuracy: 0.7435
# Epoch 63/200
# 12/12 - 0s - loss: 0.5340 - accuracy: 0.7435
# Epoch 64/200
# 12/12 - 0s - loss: 0.5320 - accuracy: 0.7435
# Epoch 65/200
# 12/12 - 0s - loss: 0.5320 - accuracy: 0.7435
# Epoch 66/200
# 12/12 - 0s - loss: 0.5303 - accuracy: 0.7435
# Epoch 67/200
# 12/12 - 0s - loss: 0.5293 - accuracy: 0.7382
# Epoch 68/200
# 12/12 - 0s - loss: 0.5286 - accuracy: 0.7330
# Epoch 69/200
# 12/12 - 0s - loss: 0.5279 - accuracy: 0.7382
# Epoch 70/200
# 12/12 - 0s - loss: 0.5285 - accuracy: 0.7382
# Epoch 71/200
# 12/12 - 0s - loss: 0.5270 - accuracy: 0.7382
# Epoch 72/200
# 12/12 - 0s - loss: 0.5257 - accuracy: 0.7382
# Epoch 73/200
# 12/12 - 0s - loss: 0.5250 - accuracy: 0.7382
# Epoch 74/200
# 12/12 - 0s - loss: 0.5249 - accuracy: 0.7382
# Epoch 75/200
# 12/12 - 0s - loss: 0.5238 - accuracy: 0.7382
# Epoch 76/200
# 12/12 - 0s - loss: 0.5236 - accuracy: 0.7382
# Epoch 77/200
# 12/12 - 0s - loss: 0.5233 - accuracy: 0.7330
# Epoch 78/200
# 12/12 - 0s - loss: 0.5217 - accuracy: 0.7382
# Epoch 79/200
# 12/12 - 0s - loss: 0.5215 - accuracy: 0.7382
# Epoch 80/200
# 12/12 - 0s - loss: 0.5216 - accuracy: 0.7435
# Epoch 81/200
# 12/12 - 0s - loss: 0.5201 - accuracy: 0.7487
# Epoch 82/200
# 12/12 - 0s - loss: 0.5198 - accuracy: 0.7382
# Epoch 83/200
# 12/12 - 0s - loss: 0.5191 - accuracy: 0.7382
# Epoch 84/200
# 12/12 - 0s - loss: 0.5192 - accuracy: 0.7382
# Epoch 85/200
# 12/12 - 0s - loss: 0.5182 - accuracy: 0.7382
# Epoch 86/200
# 12/12 - 0s - loss: 0.5175 - accuracy: 0.7435
# Epoch 87/200
# 12/12 - 0s - loss: 0.5167 - accuracy: 0.7435
# Epoch 88/200
# 12/12 - 0s - loss: 0.5164 - accuracy: 0.7435
# Epoch 89/200
# 12/12 - 0s - loss: 0.5163 - accuracy: 0.7382
# Epoch 90/200
# 12/12 - 0s - loss: 0.5169 - accuracy: 0.7382
# Epoch 91/200
# 12/12 - 0s - loss: 0.5159 - accuracy: 0.7382
# Epoch 92/200
# 12/12 - 0s - loss: 0.5155 - accuracy: 0.7382
# Epoch 93/200
# 12/12 - 0s - loss: 0.5143 - accuracy: 0.7382
# Epoch 94/200
# 12/12 - 0s - loss: 0.5137 - accuracy: 0.7382
# Epoch 95/200
# 12/12 - 0s - loss: 0.5131 - accuracy: 0.7382
# Epoch 96/200
# 12/12 - 0s - loss: 0.5130 - accuracy: 0.7382
# Epoch 97/200
# 12/12 - 0s - loss: 0.5129 - accuracy: 0.7487
# Epoch 98/200
# 12/12 - 0s - loss: 0.5120 - accuracy: 0.7487
# Epoch 99/200
# 12/12 - 0s - loss: 0.5123 - accuracy: 0.7435
# Epoch 100/200
# 12/12 - 0s - loss: 0.5119 - accuracy: 0.7487
# Epoch 101/200
# 12/12 - 0s - loss: 0.5118 - accuracy: 0.7487
# Epoch 102/200
# 12/12 - 0s - loss: 0.5109 - accuracy: 0.7487
# Epoch 103/200
# 12/12 - 0s - loss: 0.5110 - accuracy: 0.7539
# Epoch 104/200
# 12/12 - 0s - loss: 0.5105 - accuracy: 0.7592
# Epoch 105/200
# 12/12 - 0s - loss: 0.5097 - accuracy: 0.7487
# Epoch 106/200
# 12/12 - 0s - loss: 0.5094 - accuracy: 0.7487
# Epoch 107/200
# 12/12 - 0s - loss: 0.5093 - accuracy: 0.7487
# Epoch 108/200
# 12/12 - 0s - loss: 0.5090 - accuracy: 0.7487
# Epoch 109/200
# 12/12 - 0s - loss: 0.5082 - accuracy: 0.7487
# Epoch 110/200
# 12/12 - 0s - loss: 0.5086 - accuracy: 0.7487
# Epoch 111/200
# 12/12 - 0s - loss: 0.5076 - accuracy: 0.7539
# Epoch 112/200
# 12/12 - 0s - loss: 0.5074 - accuracy: 0.7487
# Epoch 113/200
# 12/12 - 0s - loss: 0.5074 - accuracy: 0.7487
# Epoch 114/200
# 12/12 - 0s - loss: 0.5066 - accuracy: 0.7487
# Epoch 115/200
# 12/12 - 0s - loss: 0.5067 - accuracy: 0.7539
# Epoch 116/200
# 12/12 - 0s - loss: 0.5063 - accuracy: 0.7539
# Epoch 117/200
# 12/12 - 0s - loss: 0.5058 - accuracy: 0.7592
# Epoch 118/200
# 12/12 - 0s - loss: 0.5059 - accuracy: 0.7539
# Epoch 119/200
# 12/12 - 0s - loss: 0.5053 - accuracy: 0.7592
# Epoch 120/200
# 12/12 - 0s - loss: 0.5045 - accuracy: 0.7592
# Epoch 121/200
# 12/12 - 0s - loss: 0.5053 - accuracy: 0.7592
# Epoch 122/200
# 12/12 - 0s - loss: 0.5062 - accuracy: 0.7539
# Epoch 123/200
# 12/12 - 0s - loss: 0.5039 - accuracy: 0.7696
# Epoch 124/200
# 12/12 - 0s - loss: 0.5046 - accuracy: 0.7592
# Epoch 125/200
# 12/12 - 0s - loss: 0.5033 - accuracy: 0.7644
# Epoch 126/200
# 12/12 - 0s - loss: 0.5032 - accuracy: 0.7644
# Epoch 127/200
# 12/12 - 0s - loss: 0.5025 - accuracy: 0.7696
# Epoch 128/200
# 12/12 - 0s - loss: 0.5026 - accuracy: 0.7644
# Epoch 129/200
# 12/12 - 0s - loss: 0.5019 - accuracy: 0.7644
# Epoch 130/200
# 12/12 - 0s - loss: 0.5025 - accuracy: 0.7644
# Epoch 131/200
# 12/12 - 0s - loss: 0.5019 - accuracy: 0.7644
# Epoch 132/200
# 12/12 - 0s - loss: 0.5015 - accuracy: 0.7644
# Epoch 133/200
# 12/12 - 0s - loss: 0.5029 - accuracy: 0.7801
# Epoch 134/200
# 12/12 - 0s - loss: 0.5024 - accuracy: 0.7749
# Epoch 135/200
# 12/12 - 0s - loss: 0.5007 - accuracy: 0.7644
# Epoch 136/200
# 12/12 - 0s - loss: 0.5012 - accuracy: 0.7696
# Epoch 137/200
# 12/12 - 0s - loss: 0.5020 - accuracy: 0.7749
# Epoch 138/200
# 12/12 - 0s - loss: 0.5004 - accuracy: 0.7801
# Epoch 139/200
# 12/12 - 0s - loss: 0.4996 - accuracy: 0.7696
# Epoch 140/200
# 12/12 - 0s - loss: 0.4988 - accuracy: 0.7801
# Epoch 141/200
# 12/12 - 0s - loss: 0.4986 - accuracy: 0.7696
# Epoch 142/200
# 12/12 - 0s - loss: 0.4986 - accuracy: 0.7749
# Epoch 143/200
# 12/12 - 0s - loss: 0.4981 - accuracy: 0.7749
# Epoch 144/200
# 12/12 - 0s - loss: 0.4994 - accuracy: 0.7801
# Epoch 145/200
# 12/12 - 0s - loss: 0.4973 - accuracy: 0.7853
# Epoch 146/200
# 12/12 - 0s - loss: 0.4982 - accuracy: 0.7853
# Epoch 147/200
# 12/12 - 0s - loss: 0.4968 - accuracy: 0.7801
# Epoch 148/200
# 12/12 - 0s - loss: 0.4968 - accuracy: 0.7801
# Epoch 149/200
# 12/12 - 0s - loss: 0.4977 - accuracy: 0.7801
# Epoch 150/200
# 12/12 - 0s - loss: 0.4965 - accuracy: 0.7906
# Epoch 151/200
# 12/12 - 0s - loss: 0.4955 - accuracy: 0.7906
# Epoch 152/200
# 12/12 - 0s - loss: 0.4958 - accuracy: 0.7801
# Epoch 153/200
# 12/12 - 0s - loss: 0.4955 - accuracy: 0.7801
# Epoch 154/200
# 12/12 - 0s - loss: 0.4956 - accuracy: 0.7958
# Epoch 155/200
# 12/12 - 0s - loss: 0.4961 - accuracy: 0.7853
# Epoch 156/200
# 12/12 - 0s - loss: 0.4944 - accuracy: 0.7906
# Epoch 157/200
# 12/12 - 0s - loss: 0.4940 - accuracy: 0.7958
# Epoch 158/200
# 12/12 - 0s - loss: 0.4940 - accuracy: 0.7906
# Epoch 159/200
# 12/12 - 0s - loss: 0.4938 - accuracy: 0.7801
# Epoch 160/200
# 12/12 - 0s - loss: 0.4933 - accuracy: 0.7853
# Epoch 161/200
# 12/12 - 0s - loss: 0.4936 - accuracy: 0.7958
# Epoch 162/200
# 12/12 - 0s - loss: 0.4929 - accuracy: 0.7958
# Epoch 163/200
# 12/12 - 0s - loss: 0.4932 - accuracy: 0.7853
# Epoch 164/200
# 12/12 - 0s - loss: 0.4932 - accuracy: 0.7853
# Epoch 165/200
# 12/12 - 0s - loss: 0.4922 - accuracy: 0.7906
# Epoch 166/200
# 12/12 - 0s - loss: 0.4918 - accuracy: 0.7906
# Epoch 167/200
# 12/12 - 0s - loss: 0.4916 - accuracy: 0.7958
# Epoch 168/200
# 12/12 - 0s - loss: 0.4920 - accuracy: 0.7958
# Epoch 169/200
# 12/12 - 0s - loss: 0.4909 - accuracy: 0.7958
# Epoch 170/200
# 12/12 - 0s - loss: 0.4909 - accuracy: 0.7958
# Epoch 171/200
# 12/12 - 0s - loss: 0.4905 - accuracy: 0.7958
# Epoch 172/200
# 12/12 - 0s - loss: 0.4907 - accuracy: 0.7958
# Epoch 173/200
# 12/12 - 0s - loss: 0.4902 - accuracy: 0.7958
# Epoch 174/200
# 12/12 - 0s - loss: 0.4897 - accuracy: 0.7958
# Epoch 175/200
# 12/12 - 0s - loss: 0.4892 - accuracy: 0.7958
# Epoch 176/200
# 12/12 - 0s - loss: 0.4896 - accuracy: 0.7958
# Epoch 177/200
# 12/12 - 0s - loss: 0.4894 - accuracy: 0.7906
# Epoch 178/200
# 12/12 - 0s - loss: 0.4890 - accuracy: 0.7958
# Epoch 179/200
# 12/12 - 0s - loss: 0.4885 - accuracy: 0.7958
# Epoch 180/200
# 12/12 - 0s - loss: 0.4884 - accuracy: 0.7958
# Epoch 181/200
# 12/12 - 0s - loss: 0.4879 - accuracy: 0.7958
# Epoch 182/200
# 12/12 - 0s - loss: 0.4886 - accuracy: 0.7906
# Epoch 183/200
# 12/12 - 0s - loss: 0.4873 - accuracy: 0.7958
# Epoch 184/200
# 12/12 - 0s - loss: 0.4876 - accuracy: 0.7958
# Epoch 185/200
# 12/12 - 0s - loss: 0.4885 - accuracy: 0.7853
# Epoch 186/200
# 12/12 - 0s - loss: 0.4866 - accuracy: 0.7906
# Epoch 187/200
# 12/12 - 0s - loss: 0.4877 - accuracy: 0.7958
# Epoch 188/200
# 12/12 - 0s - loss: 0.4864 - accuracy: 0.8010
# Epoch 189/200
# 12/12 - 0s - loss: 0.4859 - accuracy: 0.7906
# Epoch 190/200
# 12/12 - 0s - loss: 0.4859 - accuracy: 0.8010
# Epoch 191/200
# 12/12 - 0s - loss: 0.4853 - accuracy: 0.7958
# Epoch 192/200
# 12/12 - 0s - loss: 0.4852 - accuracy: 0.7958
# Epoch 193/200
# 12/12 - 0s - loss: 0.4853 - accuracy: 0.7853
# Epoch 194/200
# 12/12 - 0s - loss: 0.4842 - accuracy: 0.7958
# Epoch 195/200
# 12/12 - 0s - loss: 0.4842 - accuracy: 0.8010
# Epoch 196/200
# 12/12 - 0s - loss: 0.4847 - accuracy: 0.7958
# Epoch 197/200
# 12/12 - 0s - loss: 0.4842 - accuracy: 0.8010
# Epoch 198/200
# 12/12 - 0s - loss: 0.4859 - accuracy: 0.7749
# Epoch 199/200
# 12/12 - 0s - loss: 0.4831 - accuracy: 0.7801
# Epoch 200/200
# 12/12 - 0s - loss: 0.4830 - accuracy: 0.8010

# %%
_, accuracy = model.evaluate(features_test_enc, target_test_enc, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 69.47
